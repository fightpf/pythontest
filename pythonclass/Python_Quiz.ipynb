# %% [markdown]
# ## Quiz Question 1: Given a data string, which includes several Gmail accounts and their time of usage accordingly (in minutes).
#
# 1. Convert all the time of usage into hours and minutes. ex: 123mins -> 2hrs 3mins
#
# 2. Extract all mail accounts to build a list of accout ex: 'J0RB8BMRQU@gmail.com' ->  ['J0RB8BMRQU']

# %%
data_str = 'J0RB8BMRQU@gmail.com,4699\nLEKUUWH7QG@gmail.com,3443\nED61NHVAKH@gmail.com,2436\nBLNJKE6MOT@gmail.com,700\nWX79DJ3GBX@gmail.com,4585\n89RNWHB29T@gmail.com,3502\nDBSDKRY0M5@gmail.com,5704\n1VCSTNN5DT@gmail.com,8859\nQJ5GSY0Y7O@gmail.com,5676\n8LI30OUMNO@gmail.com,2375\nZWRZ4E4QN8@gmail.com,3783\n2R2001VJRH@gmail.com,5272\nXR4Q2992I2@gmail.com,6403\nQ7S1VG75BQ@gmail.com,5316\nIBSNP0S0KG@gmail.com,320\nVCBMQ40FNN@gmail.com,7738\nQSHRIT977Q@gmail.com,9183\n5JGZSS2QPB@gmail.com,8964\nRL0U9FCRT9@gmail.com,4093\nJI8F4EY4CA@gmail.com,184\n5XKR544N7Q@gmail.com,5858\nOI278Z7NYZ@gmail.com,8980\nD389NLF4BC@gmail.com,9378\nIVP4KUWQ7U@gmail.com,3759\n1ET6L0BAC9@gmail.com,6997\n0S4QQBJFDL@gmail.com,8143\nGXG5SM11ZX@gmail.com,2580\n7HN1DMLO5B@gmail.com,5483\n5YORL6N7NR@gmail.com,3619\n7PM5UTQP2R@gmail.com,6578'

# %%
# Enter your anwser here!

# %% [markdown]
# ## Quiz Question 2: Write a Fibonacci generator, starting from 0, that generates the Fibonacci sequence less than **max_number**
#
# Ex. if max_number == 5 and fib_generator is your answer
#
# next(fib_generator) # 0
#
# next(fib_generator) # 1
#
# next(fib_generator) # 1
#
# next(fib_generator) # 2
#
# next(fib_generator) # 3
#
# next(fib_generator) # Stop iteration
#
# use **check** module function **ex2_1** to verify your answer

# %%
# Enter your anwser here!

# %% [markdown]
# ## Quiz Question 3:
#
# 1. Write a class named **Rectangle** including 2 properties named **width** and **height** and a member function **area** which calculate the area of rectangle
#
# 2. Write a class named **Student** which includes a member function **calculate** accepting 2 rectangle objects as input and return the sum of area
#
# 3. Set the 2 rectangle objects with (width, height) = (2,3), (3,4)
#
# use **check** module function **ex2_2** to verify your answer

# %%
# Enter your anwser here!
class Rectangle():
  def _init_(self, width, length):
    self.width = width 
    self.length = length
  def

# %% [markdown]
# ## Quiz Question 4:
# Make a scatter matrix using the iris data, it should look something like this
# ![alt text](https://i.stack.imgur.com/27rxN.png)
#
# You can get the iris data by using the following code
# ```python
# from sklearn import datasets
# iris = datasets.load_iris()
# ```

# %%
# Enter your anwser here!
