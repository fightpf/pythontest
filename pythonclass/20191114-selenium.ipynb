# %%
from selenium import webdriver
driver = webdriver.Chrome('chromedriver')
driver.get('https://comicbus.live/online/manga_14132.html?ch=182')

# %%
#driver.page_source

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'lxml')
print('https:' + soup.select_one('#TheImg').get('src'))
# Out:
# https://img4.8comic.com/4/14132/182/001_89T.jpg

# %%
import requests
res = requests.get('https://img4.8comic.com/4/14132/182/001_89T.jpg')
with open('test.jpg', 'wb') as f:
    f.write(res.content)

# %%
from PIL import Image
Image.open('test.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=756x1100 at 0x22FB6380668>

# %%
pagenum = int(soup.select_one('#pagenum').text.split('/')[1].strip('頁'))

# %%
import time
pageurl = 'https://comicbus.live/online/manga_14132.html?ch=182-{}'
for i in range(pagenum):
    driver.get(pageurl.format(i+1))
    soup = BeautifulSoup(driver.page_source, 'lxml')
    imgurl = 'https:' + soup.select_one('#TheImg').get('src')
    print(imgurl)
    res = requests.get(imgurl)
    with open('{}.jpg'.format(i), 'wb') as f:
        f.write(res.content)
    time.sleep(1)
# Out:
# https://img4.8comic.com/4/14132/182/001_89T.jpg
# https://img4.8comic.com/4/14132/182/002_WNp.jpg
# https://img4.8comic.com/4/14132/182/003_P89.jpg
# https://img4.8comic.com/4/14132/182/004_qpg.jpg
# https://img4.8comic.com/4/14132/182/005_rf2.jpg
# https://img4.8comic.com/4/14132/182/006_wvS.jpg
# https://img4.8comic.com/4/14132/182/007_w4H.jpg
# https://img4.8comic.com/4/14132/182/008_Hjv.jpg
# https://img4.8comic.com/4/14132/182/009_6EC.jpg
# https://img4.8comic.com/4/14132/182/010_g3C.jpg
# https://img4.8comic.com/4/14132/182/011_9TW.jpg
# https://img4.8comic.com/4/14132/182/012_NpP.jpg
# https://img4.8comic.com/4/14132/182/013_89q.jpg
# https://img4.8comic.com/4/14132/182/014_pgr.jpg
# https://img4.8comic.com/4/14132/182/015_f2w.jpg
# https://img4.8comic.com/4/14132/182/016_vSw.jpg
# https://img4.8comic.com/4/14132/182/017_4HH.jpg
# https://img4.8comic.com/4/14132/182/018_jv6.jpg
# https://img4.8comic.com/4/14132/182/019_ECg.jpg
# https://img4.8comic.com/4/14132/182/020_3CE.jpg
# https://img4.8comic.com/4/14132/182/021_TWN.jpg
# https://img4.8comic.com/4/14132/182/022_pP8.jpg
